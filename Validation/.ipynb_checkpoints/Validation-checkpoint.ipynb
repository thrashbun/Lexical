# %%
import json
import spacy
import pickle
import itertools
from spacy.lang.en.stop_words import STOP_WORDS

# %%
with open("output.manifest") as fp:
    objects=[json.loads(object) for object in fp]

# %%
queries={}
for object in objects:
    for annotation in object['circumlocutions-all']['annotationsFromAllWorkers']:
            content=annotation['annotationData']['content']
            if len(content)>5 and len(content)<120 and nlp(object['source'])[0].vector_norm>.001 and ' ' not in  object['source'] and '/' not in  object['source']:
                queries[json.loads(content)['group']]=object['source']

# %%
num=len(queries)

# %%
nlp = spacy.load('/home/jcolbert/anaconda3/envs/lexical/lib/python3.6/site-packages/en_vectors_web_lg/en_vectors_web_lg-2.0.0')

# %%
test_words = pickle.load(open('../PSUTherapy/words.p','rb'))
test_words=list(itertools.chain.from_iterable([test_words[key] for key in test_words.keys()]))
test_tokens=[nlp(word)[0] for word in test_words]
test_tokens=[token for token in test_tokens if token.vector_norm>.0001]

# %%
for word in STOP_WORDS:
    for w in (word, word[0].capitalize(), word.upper()):
        lex = nlp_core.vocab[w]
        lex.is_stop = True
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-c76f0a3bf05f> in <module>
# ----> 1 nlp_core=spacy.load('en_core_web_lg')
#       2 for word in STOP_WORDS:
#       3     for w in (word, word[0].capitalize(), word.upper()):
#       4         lex = nlp_core.vocab[w]
#       5         lex.is_stop = True
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/spacy/__init__.py in load(name, **overrides)
#      19     if depr_path not in (True, False, None):
#      20         deprecation_warning(Warnings.W001.format(path=depr_path))
# ---> 21     return util.load_model(name, **overrides)
#      22
#      23
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/spacy/util.py in load_model(name, **overrides)
#     110     if isinstance(name, basestring_):  # in data dir / shortcut
#     111         if name in set([d.name for d in data_path.iterdir()]):
# --> 112             return load_model_from_link(name, **overrides)
#     113         if is_package(name):  # installed as package
#     114             return load_model_from_package(name, **overrides)
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/spacy/util.py in load_model_from_link(name, **overrides)
#     127     except AttributeError:
#     128         raise IOError(Errors.E051.format(name=name))
# --> 129     return cls.load(**overrides)
#     130
#     131
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/spacy/data/en_core_web_lg/__init__.py in load(**overrides)
#      10
#      11 def load(**overrides):
# ---> 12     return load_model_from_init_py(__file__, **overrides)
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/spacy/util.py in load_model_from_init_py(init_file, **overrides)
#     171     if not model_path.exists():
#     172         raise IOError(Errors.E052.format(path=path2str(data_path)))
# --> 173     return load_model_from_path(data_path, meta, **overrides)
#     174
#     175
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/spacy/util.py in load_model_from_path(model_path, meta, **overrides)
#     154             component = nlp.create_pipe(name, config=config)
#     155             nlp.add_pipe(component, name=name)
# --> 156     return nlp.from_disk(model_path)
#     157
#     158
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/spacy/language.py in from_disk(self, path, disable)
#     645         if not (path / 'vocab').exists():
#     646             exclude['vocab'] = True
# --> 647         util.from_disk(path, deserializers, exclude)
#     648         self._path = path
#     649         return self
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/spacy/util.py in from_disk(path, readers, exclude)
#     509     for key, reader in readers.items():
#     510         if key not in exclude:
# --> 511             reader(path / key)
#     512     return path
#     513
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/spacy/language.py in <lambda>(p)
#     633             ('meta.json', lambda p: self.meta.update(util.read_json(p))),
#     634             ('vocab', lambda p: (
# --> 635                 self.vocab.from_disk(p) and _fix_pretrained_vectors_name(self))),
#     636             ('tokenizer', lambda p: self.tokenizer.from_disk(p, vocab=False)),
#     637         ))
#
# vocab.pyx in spacy.vocab.Vocab.from_disk()
#
# vectors.pyx in spacy.vectors.Vectors.from_disk()
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/spacy/util.py in from_disk(path, readers, exclude)
#     509     for key, reader in readers.items():
#     510         if key not in exclude:
# --> 511             reader(path / key)
#     512     return path
#     513
#
# vectors.pyx in spacy.vectors.Vectors.from_disk.load_vectors()
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/numpy/lib/npyio.py in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
#     431             else:
#     432                 return format.read_array(fid, allow_pickle=allow_pickle,
# --> 433                                          pickle_kwargs=pickle_kwargs)
#     434         else:
#     435             # Try a pickle
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/numpy/lib/format.py in read_array(fp, allow_pickle, pickle_kwargs)
#     696             array = array.transpose()
#     697         else:
# --> 698             array.shape = shape
#     699
#     700     return array
#
# ValueError: cannot reshape array of size 0 into shape (684831,300)

# %%
query="A orange vegetable that bus bunny eats"

# %%
doc=nlp(query.lower())

# %%
get_scored_words(nlp(''.join([token.string for token in doc if not token.is_stop])))
# Out:
# [('orange', 0.7066666578209024),
#  ('carrot', 0.6572613744763355),
#  ('banana', 0.6528253537783654),
#  ('strawberry', 0.6162683706802764),
#  ('potato', 0.6160069796719414),
#  ('egg', 0.6011352370200768),
#  ('cheese', 0.5990258025809345),
#  ('rabbit', 0.5958958816400495),
#  ('tomato', 0.5938811926075166),
#  ('cake', 0.5919060036909862),
#  ('bread', 0.5902431328760251),
#  ('butter', 0.5894558713447672),
#  ('peanut', 0.5894504354389264),
#  ('lemon', 0.5856990262666096),
#  ('cow', 0.5774356073861284),
#  ('goat', 0.5748330793260992),
#  ('watermelon', 0.5685497426530849),
#  ('pig', 0.5664280013109673),
#  ('peach', 0.5647413120071644),
#  ('onion', 0.5614212389330497),
#  ('lime', 0.561320372961227),
#  ('apple', 0.5581736447897863),
#  ('sandwich', 0.5570775909540457),
#  ('pineapple', 0.5558083410941002),
#  ('coconut', 0.5486445338137325),
#  ('corn', 0.5467439331848721),
#  ('cat', 0.5444472521180241),
#  ('pizza', 0.5376491084800256),
#  ('crab', 0.532029059067422),
#  ('baby', 0.5293441374352138),
#  ('dog', 0.5283381029953442),
#  ('mushroom', 0.5266824838677315),
#  ('celery', 0.5227877290143327),
#  ('mango', 0.5226801163840037),
#  ('fish', 0.5209127238343493),
#  ('cherry', 0.5176587909794885),
#  ('lettuce', 0.5133439459281803),
#  ('elephant', 0.5116809012032896),
#  ('monkey', 0.5103834339045942),
#  ('dish', 0.5100843597965483),
#  ('squirrel', 0.5097764662028312),
#  ('girl', 0.5075266219313128),
#  ('bird', 0.5071220571776616),
#  ('peas', 0.5045524243883942),
#  ('blueberry', 0.5040284794772211),
#  ('bear', 0.49799168412649863),
#  ('salt', 0.4972885363006798),
#  ('hot', 0.49541153949280603),
#  ('snake', 0.49278182023543415),
#  ('bowl', 0.492140397219626),
#  ('cookie', 0.4885649142715898),
#  ('pot', 0.48785566436572025),
#  ('boy', 0.4877386291417083),
#  ('asparagus', 0.48692039889448757),
#  ('popcorn', 0.48453543100591623),
#  ('frog', 0.4818433744525965),
#  ('turtle', 0.48126216743355293),
#  ('cup', 0.4800057447437449),
#  ('plum', 0.477445222174336),
#  ('cranberry', 0.4769660308361507),
#  ('crackers', 0.47544093519495034),
#  ('spoon', 0.475361952740872),
#  ('apricot', 0.47255523726788984),
#  ('tiger', 0.47142840202081787),
#  ('kiwi', 0.468211716313689),
#  ('bag', 0.4678987443439599),
#  ('wheat', 0.4673993388516828),
#  ('lobster', 0.4667075814936777),
#  ('couch', 0.46513734965169506),
#  ('vanilla', 0.46435867409598597),
#  ('bee', 0.4616411572457054),
#  ('water', 0.45914701333123237),
#  ('donkey', 0.45845957050619685),
#  ('raisin', 0.4565593618317613),
#  ('pear', 0.4551687065027507),
#  ('basket', 0.45406930200606493),
#  ('spaghetti', 0.45388387649164724),
#  ('camel', 0.45281778750037066),
#  ('grapefruit', 0.4491744754267322),
#  ('snow', 0.44877335931938395),
#  ('bucket', 0.4481467272717088),
#  ('nut', 0.44490946904656853),
#  ('house', 0.44356276666913413),
#  ('deer', 0.44310621714352755),
#  ('spider', 0.4406249630011931),
#  ('radish', 0.4389186876521455),
#  ('taxi', 0.4378591942243704),
#  ('grapes', 0.4371806500051408),
#  ('papaya', 0.4365714303036991),
#  ('butterfly', 0.43574730116890703),
#  ('wine', 0.43546100124671894),
#  ('sheep', 0.43261341233308453),
#  ('lion', 0.4315753114739984),
#  ('finger', 0.4306079325584022),
#  ('tail', 0.42950105157162183),
#  ('subway', 0.4287124772608401),
#  ('giraffe', 0.42541354398669795),
#  ('bottle', 0.42157695569637416),
#  ('coat', 0.42085439576826905),
#  ('octopus', 0.42079289703690165),
#  ('whip', 0.41902095757742364),
#  ('pomegranate', 0.41870385811157135),
#  ('bed', 0.4185150679833166),
#  ('horse', 0.41774515986099114),
#  ('doll', 0.4171085341727997),
#  ('panda', 0.41708511853420943),
#  ('brush', 0.41703136593573514),
#  ('paw', 0.41647940240615183),
#  ('zebra', 0.4160335994236299),
#  ('street', 0.41284361622702026),
#  ('fox', 0.412824950243474),
#  ('toilet', 0.4128045862411479),
#  ('artichoke', 0.41265240059078984),
#  ('clown', 0.41227435662230233),
#  ('hand', 0.4109801084981195),
#  ('alligator', 0.41028645737831204),
#  ('fig', 0.41015713664802467),
#  ('lizard', 0.40977886744884706),
#  ('love', 0.40951174266241686),
#  ('jar', 0.4077186256541313),
#  ('snowman', 0.406604235760159),
#  ('barbecue', 0.40648990548295505),
#  ('woman', 0.40639036292410496),
#  ('skunk', 0.40618176170727377),
#  ('man', 0.40615521490294537),
#  ('glass', 0.4059357735909242),
#  ('nose', 0.4057551413277016),
#  ('pan', 0.4037509007439991),
#  ('waffle', 0.40168919673603404),
#  ('shark', 0.40155937881150755),
#  ('hang', 0.4014162063332561),
#  ('pillow', 0.40029874623284445),
#  ('hair', 0.40013880333786667),
#  ('picture', 0.400017111211541),
#  ('paint', 0.3978830159815041),
#  ('plate', 0.397552418172071),
#  ('kangaroo', 0.39657375133723033),
#  ('beaver', 0.3958545708420223),
#  ('ladybug', 0.39402923473110363),
#  ('moose', 0.3931485694318043),
#  ('trolley', 0.3919374120010392),
#  ('candle', 0.39127889061002963),
#  ('apron', 0.3876165803654359),
#  ('snail', 0.38486714085462587),
#  ('guava', 0.3842141334477793),
#  ('ant', 0.3839790089698762),
#  ('box', 0.38290022439389976),
#  ('dinosaur', 0.38287445394180425),
#  ('well', 0.3800363416056396),
#  ('jack', 0.37993933045480965),
#  ('road', 0.379684061227347),
#  ('leopard', 0.37900456060974674),
#  ('walnut', 0.37570868179356803),
#  ('worm', 0.3753789464896376),
#  ('suitcase', 0.37494627292913363),
#  ('teeth', 0.374873972698142),
#  ('raccoon', 0.37381765451676824),
#  ('shower', 0.3728486821441273),
#  ('refrigerator', 0.36983170768528756),
#  ('ball', 0.3694291128720689),
#  ('can', 0.3689470673606887),
#  ('whale', 0.36839292775685084),
#  ('stairs', 0.3678964356202335),
#  ('waiter', 0.366875745390968),
#  ('pajamas', 0.36636403587652955),
#  ('broom', 0.3660638330060895),
#  ('night', 0.3655304282858192),
#  ('wolf', 0.3652159545492923),
#  ('bomb', 0.3642069638000224),
#  ('lipstick', 0.3632866160271247),
#  ('prune', 0.36197340459220667),
#  ('glasses', 0.36139645811584614),
#  ('knife', 0.3587082824395221),
#  ('cross', 0.35814366166194017),
#  ('lips', 0.3577312006875308),
#  ('leg', 0.3571036012563066),
#  ('shell', 0.35654899047815036),
#  ('city', 0.35654743339484496),
#  ('balloon', 0.355530867311357),
#  ('eye', 0.3555126790469105),
#  ('fountain', 0.3550030041399869),
#  ('mouse', 0.3545506978878615),
#  ('pool', 0.35423147552562045),
#  ('fence', 0.35345192220519084),
#  ('dolphin', 0.3523533433630335),
#  ('table', 0.35225018515973755),
#  ('shovel', 0.3521862378709027),
#  ('foot', 0.35178012120035546),
#  ('robot', 0.3516453610898264),
#  ('safe', 0.350717859186614),
#  ('cowboy', 0.3483259442621688),
#  ('door', 0.3477186330431433),
#  ('waste', 0.34739925789156345),
#  ('block', 0.3464944499313436),
#  ('grasshopper', 0.3446989773752545),
#  ('feather', 0.34432009001096037),
#  ('iron', 0.34411601576258144),
#  ('shorts', 0.3430596414940803),
#  ('fork', 0.34263493795198086),
#  ('jeans', 0.34240227537131407),
#  ('beard', 0.3419483627664539),
#  ('queen', 0.3397983170434556),
#  ('carpet', 0.33948375940475134),
#  ('gorilla', 0.33916771667530626),
#  ('fly', 0.336941279447392),
#  ('bricks', 0.336898584774694),
#  ('bug', 0.33608423402325593),
#  ('rope', 0.33587160502683683),
#  ('crib', 0.33465731678353766),
#  ('saw', 0.33456618048973835),
#  ('pencil', 0.33411373191312543),
#  ('wallet', 0.333585782442783),
#  ('rug', 0.3331583961887268),
#  ('cape', 0.3331192594977963),
#  ('nail', 0.3318849460791111),
#  ('roof', 0.33091922885027886),
#  ('window', 0.3306743357364368),
#  ('clock', 0.327804446275161),
#  ('top', 0.3277347677153268),
#  ('uniform', 0.3265604443553702),
#  ('trunk', 0.3265152229976247),
#  ('bone', 0.3262493986928622),
#  ('feet', 0.3255630037941476),
#  ('magnet', 0.32454677592736375),
#  ('llama', 0.324452632949767),
#  ('skeleton', 0.32434862608120013),
#  ('toaster', 0.3236872033629248),
#  ('plantain', 0.32366278229951373),
#  ('nurse', 0.3233383732895925),
#  ('scorpion', 0.32318021292905263),
#  ('ear', 0.3218883964374985),
#  ('doctor', 0.3216868701488487),
#  ('buggy', 0.32076891021847603),
#  ('suit', 0.32058861030263336),
#  ('lamp', 0.31959056261103513),
#  ('moving', 0.31769601212598064),
#  ('cigarette', 0.31717341152907136),
#  ('floor', 0.3170138899604613),
#  ('desk', 0.31648075417490223),
#  ('teapot', 0.31522021252862714),
#  ('hoe', 0.31500430588368455),
#  ('thumb', 0.3148001438021241),
#  ('scissors', 0.314685584597332),
#  ('lychee', 0.3136432340191481),
#  ('vase', 0.3136200682373261),
#  ('fan', 0.31289032534377076),
#  ('blackberry', 0.3126477599357453),
#  ('hood', 0.3125040156178848),
#  ('bat', 0.3112748616122043),
#  ('tent', 0.3110033379168126),
#  ('stove', 0.3084095980390762),
#  ('porcupine', 0.30828078608623244),
#  ('star', 0.30757939091671893),
#  ('tricycle', 0.30735759952439967),
#  ('curtains', 0.306076338690662),
#  ('bathtub', 0.3043524315977812),
#  ('castle', 0.30407994628500457),
#  ('cork', 0.3039415484066696),
#  ('semi', 0.30254873966512547),
#  ('stool', 0.30252672043412426),
#  ('policeman', 0.3016889988545931),
#  ('shoulder', 0.3016534621437905),
#  ('toe', 0.301378892434903),
#  ('chain', 0.3013581802936174),
#  ('pirate', 0.30128224095620953),
#  ('chair', 0.300388061067532),
#  ('flag', 0.2994881781021075),
#  ('sink', 0.29917467364787637),
#  ('closet', 0.29893396582305637),
#  ('paper', 0.2987758292260941),
#  ('gun', 0.29810343252687016),
#  ('neck', 0.29773290284084386),
#  ('hanger', 0.29746532846411217),
#  ('pyramid', 0.296730478598969),
#  ('church', 0.29599047012534463),
#  ('mosquito', 0.2952029165067144),
#  ('clementine', 0.29519102955524473),
#  ('bridge', 0.29425468853596143),
#  ('hose', 0.29405411311499746),
#  ('camera', 0.2924096932140343),
#  ('toothbrush', 0.29235612753148155),
#  ('pipe', 0.2917967175290082),
#  ('golf', 0.290345300082126),
#  ('balcony', 0.29018898053091124),
#  ('currant', 0.2897562076014814),
#  ('mop', 0.2894731407542972),
#  ('ferry', 0.288319480271948),
#  ('passionfruit', 0.2881073987806266),
#  ('arrow', 0.28697414517933784),
#  ('arm', 0.2869494147482593),
#  ('hook', 0.28647334412692377),
#  ('pen', 0.28558678711136676),
#  ('umbrella', 0.2852596411039434),
#  ('blouse', 0.2848755671261832),
#  ('barrel', 0.2848335293838667),
#  ('TV', 0.2837419094457814),
#  ('tv', 0.2837419094457814),
#  ('comb', 0.2829167263703235),
#  ('tape', 0.28032314237728356),
#  ('fireman', 0.279459075512383),
#  ('overalls', 0.2790882035605256),
#  ('jet', 0.27866548067207975),
#  ('soldier', 0.2779241494170387),
#  ('bow', 0.27558672206342094),
#  ('seal', 0.2754793613384937),
#  ('sailor', 0.27514053062679356),
#  ('acorns', 0.2741912043386018),
#  ('chest', 0.2738985861000485),
#  ('drawer', 0.27374341631571214),
#  ('robe', 0.27278643472137815),
#  ('funnel', 0.2727146062027839),
#  ('pantyhose', 0.2723278524572919),
#  ('rickshaw', 0.27175676129836085),
#  ('cannon', 0.27164415479275317),
#  ('needle', 0.27039687139043156),
#  ('thermos', 0.26805376557325133),
#  ('puzzle', 0.26778895178972667),
#  ('dresser', 0.2675409967117752),
#  ('plug', 0.2675028044241451),
#  ('statue', 0.26742122926330214),
#  ('nectarine', 0.2673048961441435),
#  ('globe', 0.26713036805763385),
#  ('mirror', 0.26659888973805634),
#  ('wing', 0.2661489893190366),
#  ('grandfather', 0.2659109623728836),
#  ('vacuum', 0.2653963564073012),
#  ('hoof', 0.26425668306163896),
#  ('bandana', 0.2636580658703484),
#  ('ski', 0.2625822879380698),
#  ('dentist', 0.2624301224098064),
#  ('windmill', 0.2615178564419277),
#  ('carousel', 0.26056754086195744),
#  ('swimsuit', 0.26050882613795423),
#  ('DVD', 0.26037897479197586),
#  ('kite', 0.2589346898858003),
#  ('lightbulb', 0.2573074301477678),
#  ('cot', 0.25704186861262834),
#  ('football', 0.25576903645728855),
#  ('flashlight', 0.2536888066878246),
#  ('underpants', 0.25329369903204896),
#  ('envelope', 0.24930022582470865),
#  ('lawnmower', 0.2487937764129247),
#  ('mixer', 0.24814352405976475),
#  ('ladder', 0.24746248385278377),
#  ('paintbrush', 0.24702118449627505),
#  ('raincoat', 0.24602071049197974),
#  ('entertainment', 0.24576672507752434),
#  ('screw', 0.24429401524239552),
#  ('antlers', 0.2432323079314526),
#  ('drum', 0.24246001920091037),
#  ('turban', 0.24152717894739473),
#  ('slipper', 0.2409567047129429),
#  ('razor', 0.2407466507017883),
#  ('hammock', 0.23841936811022782),
#  ('hammer', 0.23801890053867084),
#  ('bench', 0.23776338523769527),
#  ('grave', 0.23595664301443778),
#  ('sword', 0.23588741023289275),
#  ('whistle', 0.23439911973668187),
#  ('kumquat', 0.23424284907383816),
#  ('spatula', 0.2330807791328738),
#  ('rhinoceros', 0.23276101868595353),
#  ('present', 0.23151106625908197),
#  ('van', 0.23137581423618167),
#  ('ashtray', 0.2308199330370489),
#  ('moped', 0.23033240747373288),
#  ('pomelo', 0.22961759956136973),
#  ('walrus', 0.22882582868524087),
#  ('escalator', 0.22719374835197645),
#  ('chimney', 0.22645165753795823),
#  ('scale', 0.22622308359892146),
#  ('tuxedo', 0.2257823707554107),
#  ('hutch', 0.2255864503062363),
#  ('raft', 0.22424886187581636),
#  ('book', 0.22158380667568545),
#  ('pillar', 0.22148986561326933),
#  ('hippopotamus', 0.22106851890220292),
#  ('trashcan', 0.22039225514746902),
#  ('eskimo', 0.22017720410640232),
#  ('dime', 0.21971718856664266),
#  ('lock', 0.2195771812229636),
#  ('priest', 0.2187421930031632),
#  ('ship', 0.2175214802317945),
#  ('recliner', 0.21687208124825502),
#  ('chandelier', 0.21595171708902913),
#  ('ladle', 0.21502167439611178),
#  ('map', 0.21372410880746),
#  ('seahorse', 0.21169942734788996),
#  ('corkscrew', 0.21135081064398994),
#  ('mailbox', 0.21077842909270975),
#  ('music', 0.20844845795055347),
#  ('key', 0.20825328702243107),
#  ('ottoman', 0.20798999768159385),
#  ('nightgown', 0.206696432166653),
#  ('radio', 0.2066367367955212),
#  ('knot', 0.204944064721891),
#  ('huckleberry', 0.20277460608589487),
#  ('drill', 0.20215993666447865),
#  ('match', 0.19675254132659342),
#  ('guitar', 0.19632632533777844),
#  ('rake', 0.19624050104827942),
#  ('kayak', 0.19519066057411616),
#  ('tapestry', 0.19457869909519837),
#  ('furnace', 0.1937837044661977),
#  ('typewriter', 0.1931291268050464),
#  ('veil', 0.192308693453367),
#  ('anchor', 0.19198535765264965),
#  ('cabinet', 0.1891599072830497),
#  ('pitchfork', 0.18815875075942565),
#  ('pitcher', 0.18763770317214737),
#  ('acai', 0.18761493300420906),
#  ('wrench', 0.18638062779750733),
#  ('net', 0.18507098334390917),
#  ('telephone', 0.18421135872332797),
#  ('trumpet', 0.18171703089078403),
#  ('screwdriver', 0.17946733032134216),
#  ('leotard', 0.1792666075787041),
#  ('highchair', 0.17899196353583863),
#  ('letter', 0.17790446746091218),
#  ('pinecone', 0.17626775069350079),
#  ('piano', 0.1753619572247715),
#  ('stilts', 0.17283293040602443),
#  ('yoyo', 0.1725369280896854),
#  ('slingshot', 0.17202848885881936),
#  ('blinds', 0.1711443393268337),
#  ('suspenders', 0.16670408226596958),
#  ('microphone', 0.15961223729823873),
#  ('flute', 0.15871131475333247),
#  ('clothespin', 0.1569585008887555),
#  ('crabapple', 0.15384329160960872),
#  ('faucet', 0.14729579608763968),
#  ('ruler', 0.1447389215388116),
#  ('teepee', 0.1430079037704367),
#  ('date', 0.14174476325274465),
#  ('boysenberry', 0.14157955354129306),
#  ('binoculars', 0.13869080135827586),
#  ('clamp', 0.13751914114118358),
#  ('thimble', 0.13663926007912156),
#  ('tripod', 0.13179452523243093),
#  ('khakis', 0.1289328520524147),
#  ('violin', 0.12808730827994153),
#  ('microscope', 0.12638280025209175),
#  ('accordion', 0.12243226751182934),
#  ('catamaran', 0.12222431072186793),
#  ('hinge', 0.11716793529512547),
#  ('tweezers', 0.1152505168104073),
#  ('telescope', 0.11007312520068525),
#  ('bureau', 0.10989744729079257),
#  ('banjo', 0.10726452237251871),
#  ('toybox', 0.10540686157562837),
#  ('earmuffs', 0.10261052836108953),
#  ('pliers', 0.10212499584980374),
#  ('paperclip', 0.0997025636893053),
#  ('harp', 0.09931077997017013),
#  ('anvil', 0.0954184581276216),
#  ('stethoscope', 0.09276995764675379),
#  ('saxophone', 0.08870406262667709),
#  ('piggybank', 0.08389181388206644),
#  ('dustpan', 0.07663088825939952),
#  ('sweatsuit', 0.06606270842539261),
#  ('jumprope', 0.06235293925905583),
#  ('fishtank', 0.05350035143180718),
#  ('cummerbund', -0.0037266616527632706),
#  ('lightswitch', -0.04421369288655771)]

# %%
def get_scored_words(query):
    doc=nlp(query.lower())
    query=nlp(''.join([token.string for token in doc if not token.is_stop]))
    scores_map={token.text:query.similarity(token) for token in test_tokens}
    sorted_words = sorted(scores_map.items(), key=lambda kv: kv[1],reverse=True)
    return sorted_words

# %%
def get_rank(query):
    scored_words=get_scored_words(query[0])
    words=[scored_word[0] for scored_word in scored_words]
    return words.index(query[1])

# %%
ranks=[get_rank(query) for query in queries.items()]

# %%
len([i for i in ranks if i<10])/num
# Out:
# 0.5562231759656653

# %%
10/450
# Out:
# 0.022222222222222223

# %%
[ranks.index(max(ranks))]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-128d705b7645> in <module>
# ----> 1 queries.items()[ranks.index(max(ranks))]
#
# TypeError: 'dict_items' object does not support indexing

# %%
import requests
from bs4 import BeautifulSoup

def get_google_text(query):
    global count
    if count % 10 == 0:
        print(count)
    query=query.replace(' ','+')
    resp=requests.get("https://www.google.com/search?q=hopping+animal&oq="+query)
    soup=BeautifulSoup(resp.content)
    for script in soup(["script", "style"]):
        script.decompose()    # rip it out
    # get text
    text = soup.get_text()
    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in text.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    text = '\n'.join(chunk for chunk in chunks if chunk)
    return text

# %%
queries_subset={}
count=0
for query in queries.items():
    if count % 10==0:
        queries_subset[query[0]]=query[1]
    count=count+1

# %%
queries_subset
# Out:
# {'an orange vegetable': 'carrot',
#  ' transducer': 'microphone',
#  'something you mail letters in': 'envelope',
#  'small spike': 'nail',
#  'sticky adhesive ': 'tape',
#  'writing utensil most often made of wood with a graphite center': 'pencil',
#  'the foot of a horse': 'hoof',
#  'A kitchen utensil with a handle and flat end that is used to flip food items such as pancakes or hamburgers': 'spatula',
#  'fruit you put on top of a sundae': 'cherry',
#  'container for holding something, often made of cardboard': 'box',
#  'A handle with hair-like fabric bunched at the end for applying pigments.': 'paintbrush',
#  'a dried grape': 'raisin',
#  'black and yellow bumble': 'bee',
#  'coverage of your private parts': 'underpants',
#  'furniture to sit in front of and provide a surface to complete paperwork': 'desk',
#  'A device used for gripping': 'pliers',
#  'a garden tool that sprays water ': 'hose',
#  'measurement tool': 'ruler',
#  'symbol of country that you wave': 'flag',
#  'many types of these, table, circular, jig': 'saw',
#  'Two pieces of bread with meat in the middle': 'sandwich',
#  'A tram is a rail vehicle that runs on tramway tracks along public urban streets;': 'trolley',
#  'a string-type music instrument': 'guitar',
#  'alligator': 'alligator',
#  'a rule': 'scale',
#  'a large sea animal with thick whiskers and long tusks': 'walrus',
#  'A cylindrical object made of metal or plastic that allows liquid to flow through it.': 'pipe',
#  'A kitchen utensil with a long handle that is used to spoon out liquids such as soup': 'ladle',
#  'sharp cut fingers handle': 'scissors',
#  'a small purple fruit with a pit in the center': 'plum',
#  'a concrete structure that emits water and sometimes has fish swimming around coins on bottom': 'fountain',
#  'opposable digit on hand': 'thumb',
#  'object that holds a ship down': 'anchor',
#  'small carnivorous animal who often lives with humans, pointy ears': 'cat',
#  'another name for the straps of overalls': 'suspenders',
#  'Helathy for our body': 'boysenberry',
#  'item with 3 legs that holds a camera steady ': 'tripod',
#  'a place where people go to worship': 'church',
#  'A box like container that is used to hold clothing and other personal belongings while traveling.': 'suitcase',
#  'hot implement for removing wrinkles from clothing': 'iron',
#  'handheld rock flinger': 'slingshot',
#  'Water comes from above and is used to cleanse yourself': 'shower',
#  'a glass-sided case for keeping fish': 'fishtank',
#  'large object moved by the wind and creates energy': 'windmill',
#  'Moving stairs that go up and down on their own': 'escalator',
#  'thin fabric between worlds': 'veil',
#  'hooded vehicle': 'rickshaw',
#  'indians use this for shelter': 'teepee',
#  'leader at a Catholic Church': 'priest',
#  'a fruit eaten at christmas': 'fig',
#  'a place to keep your food cold': 'refrigerator',
#  'Network service': 'hutch',
#  'paw': 'paw',
#  'Fuzzy brown fruit that is green on the inside. Sweet taste with small, black, edible seeds inside.': 'kiwi',
#  'opening on top of house for smoke': 'chimney',
#  'a red animal with a furry tail': 'fox',
#  'facial hair on a mans cheeks and chin': 'beard',
#  'vegetable ': 'lettuce',
#  'a wild fruit that is yellow/red ': 'crabapple',
#  'Heated appliance with burners to cook on top of': 'stove',
#  'worn on the head to keep sweat and hair out of your face': 'bandana',
#  'Tool used for working with molten metals.': 'anvil',
#  'Used to save coins and money': 'piggybank',
#  'Something on your face that is used for hearing sounds': 'ear',
#  'used to store clothes': 'dresser',
#  'planes and birds have them to fly ': 'wing',
#  'feet': 'feet',
#  'Small fruit, green on outside': 'guava',
#  'this has squares in it and you eat it for breakfast': 'waffle',
#  'the tool that is used to raise a car': 'jack',
#  'light hanging fixture': 'chandelier',
#  'boat used to carry passengers ': 'ferry',
#  'a thin shelled oval in which grows the offspring of a bird': 'egg',
#  'A large fruit with green skin, orange fruit, and black seeds.': 'papaya',
#  'game with many pieces that makes a whole': 'puzzle',
#  'part of our body that lets us see': 'eye',
#  'an outfit that is worn by a man to an event or wedding': 'suit',
#  'A round fruit with a brown outer layer and a white inner layer, grown on a tree that is much like a palm': 'coconut',
#  'a very large animal that is often in water.': 'hippopotamus',
#  'dessert creature that has a deadly sting.': 'scorpion',
#  'A container made of metal that is used to heat food over a flame.': 'pot',
#  'an appendage near the rear of certain animals': 'tail',
#  'catamaran': 'catamaran',
#  'Container that holds items': 'chest',
#  'The biggest citrus fruit': 'pomelo',
#  'The round object he put flour or other': 'vase',
#  'to sit in ther': 'highchair',
#  'Animal that’s brown with horns': 'moose',
#  'another word for town': 'city',
#  'part of a tuxedo that covers the stomach and chest area': 'cummerbund',
#  'a type of cat with stripes usually black and orange ': 'tiger',
#  'noodles': 'spaghetti',
#  'Used to gather leaves together': 'rake',
#  'large brown animal': 'bear',
#  'A large animal that people often ride.': 'horse',
#  'sea animal whose male has the baby.': 'seahorse',
#  'a human being with an X and Y chromosome ': 'man',
#  'a fruit that keeps the doctor away and is tasty as a pie or turnover': 'apple',
#  'type of binocular ': 'telescope',
#  'attached to the foot': 'leg',
#  'metal and wood digging implement': 'shovel',
#  'A kitchen device used to prepare bread slices': 'toaster',
#  'something you put your clothes in found in your bedroom': 'closet',
#  'Insect which feeds on waste and food.': 'fly',
#  'law enforcer man': 'policeman',
#  'an optical instrument with a lens for each eye, used for viewing distant objects.': 'binoculars',
#  'tan colored pants': 'khakis',
#  'An animal used for wool': 'sheep',
#  'a cut in the side of a dress': 'stilts',
#  'You put these on a tray to eat with cheese': 'crackers',
#  'space in vehicle to store items': 'trunk',
#  'A gift given to someone.': 'present',
#  'what a deceased person is placed into; under the ground.': 'grave',
#  'A brown round object that you peel and you could eat': 'potato',
#  'basic instrument used by a doctor': 'stethoscope',
#  'huge grey trunked beast': 'elephant',
#  'reptile': 'lizard'}

# %%
{query[0]:query[1] in get_google_text(query[0]) for query in queries_subset.items()}
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-107-888b9e42054e> in <module>
# ----> 1 {query[0]:query[1] in get_google_text(query[0]) for query in queries.items()}
#
# <ipython-input-107-888b9e42054e> in <dictcomp>(.0)
# ----> 1 {query[0]:query[1] in get_google_text(query[0]) for query in queries.items()}
#
# <ipython-input-106-f0f3aaa14a52> in get_google_text(query)
#       4 def get_google_text(query):
#       5     query=query.replace(' ','+')
# ----> 6     resp=requests.get("https://www.google.com/search?q=hopping+animal&oq="+query)
#       7     soup=BeautifulSoup(resp.content)
#       8     for script in soup(["script", "style"]):
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/requests/api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/requests/api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/requests/models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/requests/models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     488         """
#     489         if self.chunked and self.supports_chunked_reads():
# --> 490             for line in self.read_chunked(amt, decode_content=decode_content):
#     491                 yield line
#     492         else:
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     664
#     665             while True:
# --> 666                 self._update_chunk_length()
#     667                 if self.chunk_left == 0:
#     668                     break
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/urllib3/response.py in _update_chunk_length(self)
#     596         if self.chunk_left is not None:
#     597             return
# --> 598         line = self._fp.fp.readline()
#     599         line = line.split(b';', 1)[0]
#     600         try:
#
# ~/anaconda3/envs/lexical/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     295     def recv_into(self, *args, **kwargs):
#     296         try:
# --> 297             return self.connection.recv_into(*args, **kwargs)
#     298         except OpenSSL.SSL.SysCallError as e:
#     299             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# ~/anaconda3/envs/lexical/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1819             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1820         else:
# -> 1821             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1822         self._raise_ssl_error(self._ssl, result)
#    1823
#
# KeyboardInterrupt:
